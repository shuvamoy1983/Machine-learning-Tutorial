# %% [markdown]
# <a href="https://colab.research.google.com/github/shuvamoy1983/Machine-learning-Tutorial/blob/master/NumpyTutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Numpy Tutorial
#
# Numpy *dot*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
a=np.array([[1,2],[3,4]])
b=np.array([[11,12],[13,14]])
np.dot(a,b)
# Out:
# array([[37, 40],
#        [85, 92]])

# %% [markdown]
# How it is calculated:
#
# ![image.png](data:image/png;base64,...)
